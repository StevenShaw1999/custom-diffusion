# %%
import spacy
from spacy_lookup import Entity
from spacy import displacy
ynlp = spacy.load('en_core_web_sm')
doc = 'a fluffy cat with blue eyes standing on a step.'
#'a cat standing'
docy = ynlp(doc)
displacy.render(docy,style ='dep',jupyter = True,options ={'distance':120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c03c26de4dd14f78971f3cc1d1dc61fc-0" class="displacy" width="1250" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">fluffy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
# ...
